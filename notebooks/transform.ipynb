# %% [markdown]
# #

# %%
from bs4 import BeautifulSoup as soup 
import pandas as pd
import pymongo

# %%
# Initialize Mongo 
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.raw_html_db
collection = db.job_detail

# %%
# Load data from our job detail collection in our raw_html_db database
data = pd.DataFrame(list(collection.find().limit(200)))

# %%
data.head()
# Out:
#                         _id                                           link_src
# 0  5e85d38d4284a65cb5c21372  [<html lang="en" class="artdeco"><head>\n    <...
# 1  5e85d3964284a65cb5c21373  [<html lang="en" class="artdeco"><head>\n    <...
# 2  5e85d39c4284a65cb5c21374  [<html lang="en" class="artdeco"><head>\n    <...
# 3  5e85d3a04284a65cb5c21375  [<html lang="en" class="artdeco"><head>\n    <...
# 4  5e85d3a54284a65cb5c21376  [<html lang="en" class="artdeco"><head>\n    <...

# %%
# create a list of lists that represent each row in our link src column of our data variable
link_list = []
for i in data.link_src:
    for j in i:
#       convert the raw html into a beautiful soup object we can parse later  
        link_list.extend(soup(j,'html.parser'))

# %%
# iterate through each sublist of html, parse it, save the result in a tuple then append it to a list as a dict
headers = []
job_titles = []
for idx in range(len(link_list)):  
    for x in link_list[idx].find_all('h3','jobs-top-card__company-info t-14 mt1'):
        vitals = x.get_text().replace('Company Name','').replace('Company Location','').split('\n')
        vitals = tuple([elem for elem in vitals if elem.strip()])
        headers.append({'company':vitals[0].strip(),'location':vitals[1].strip()})
    try:
        for title in link_list[idx].find('h1',"jobs-top-card__job-title t-24"):
            job_titles.append(title)
    except:
        job_titles.append('n/a')
df1 = pd.DataFrame(headers)
df2 = pd.DataFrame(job_titles)
dataset  = pd.concat([df2,df1],axis=1)
df1
# Out:
#                                                company  \
# 0                                 Gene Therapy Startup
# 1                   NBS - Local Government Consultants
# 2                                                Modis
# 3                                               TikTok
# 4                            Live Nation Entertainment
# 5                                                WebMD
# 6                                                  ALC
# 7                                             Glocomms
# 8                             Analytic Recruiting Inc.
# 9                                            Swinerton
# 10                        Kinetic Personnel Group, Inc
# 11                                          PeerStreet
# 12                                          ATMECS Inc
# 13                                         Dermalogica
# 14                                Harbor Freight Tools
# 15                                               Össur
# 16                                      Veritone, Inc.
# 17                                   Farmers Insurance
# 18                                Pacific Premier Bank
# 19                                           Snap Inc.
# 20                                              NCSOFT
# 21                                   Ultimate Staffing
# 22                    Southern California Edison (SCE)
# 23                                               Honey
# 24                      Cenergy International Services
# 25                                             Cenergy
# 26                         Disney Television Animation
# 27                                              Twitch
# 28                                        The Athletic
# 29                                            SureSale
# 30                                                Vaco
# 31                                             Harnham
# 32                                        City of Hope
# 33                                            TrueData
# 34                                    Dun & Bradstreet
# 35                                            Nexon OC
# 36                                                Hulu
# 37                                      C&L Group, LLC
# 38                                          Nativo Inc
# 39                  Naval Air Systems Command (NAVAIR)
# 40                                            Staffigo
# 41                                      East West Bank
# 42                                            Evolvinc
# 43                               Universal Music Group
# 44                                               Apple
# 45                                     The Judge Group
# 46                                            Jam City
# 47                                   HIGH BRIDGE & CO.
# 48                                            Clinique
# 49                                  City National Bank
# 50                                           Expertise
# 51                                           Cognizant
# 52                                   Scale Media, Inc.
# 53                                     Career Movement
# 54                                          Conversion
# 55                       Apollo Global Management Inc.
# 56                        Veterans Sourcing Group, LLC
# 57                                        Ingram Micro
# 58                                          Kforce Inc
# 59                                           BlackLine
# 60                                               PlayQ
# 61                                    Niagara Bottling
# 62                                          sweetgreen
# 63                                     Conversion Labs
# 64                                     CHOC Children's
# 65                                     New Reach, Inc.
# 66                                           CalOptima
# 67                                 ConsumerTrack, Inc.
# 68                                             Inspire
# 69                                 Phoenix Staff, Inc.
# 70                            KellyMitchell Group, Inc
# 71                                        Apex Systems
# 72                                              PlayVS
# 73                              Skybound Entertainment
# 74                                                Esri
# 75                                   Mercury Insurance
# 76                         Beckman Coulter Diagnostics
# 77                             Powermind Solutions Inc
# 78                                    Futran Solutions
# 79                 Strategic Employment Partners (SEP)
# 80                                         WarnerMedia
# 81                                   Beyond the Limits
# 82                             Stand Up 8 Fitness, LLC
# 83                                      Evolent Health
# 84                                          Ampcus Inc
# 85                                        INNOCEAN USA
# 86                              Lakeside Medical Group
# 87                                              Amazon
# 88                                           Flowspace
# 89              Healthcare Staffing Professionals Inc.
# 90                                            GoDiRECT
# 91                           Amazon Web Services (AWS)
# 92                               L3Harris Technologies
# 93                         Cercacor Laboratories, Inc.
# 94                                           Expertise
# 95   Center for Autism and Related Disorders, LLC. ...
# 96                                    MotorTrend Group
# 97                            Hylink Digital Solutions
# 98                             Nirvana Enterprises LLC
# 99                      Ultimate international Limited
# 100                                  San Manuel Casino
# 101                                         VelvetJobs
# 102                                          Focus GTS
# 103                                             Atrium
# 104                                Centene Corporation
# 105                                                EDO
# 106                               First American Title
# 107                           IMPEX Technologies, Inc.
# 108                                           EVERSANA
# 109                                           ASICSoft
# 110                                        Cypress HCM
# 111                                             Takeda
# 112                          Enterprise Solutions Inc.
# 113                                       My Lucky Day
# 114                                    Pacific Clinics
# 115                                             Intuit
# 116                                         Stamps.com
# 117                                     The Trade Desk
# 118                                        Malakye.com
# 119                             Ipsos in North America
# 120                             Citizens Business Bank
# 121                           San Bernardino County HR
# 122                            PowerMind Solutions LTD
# 123                                    Fox Corporation
# 124                                     Blue Icy Water
# 125                                         MWIDM Inc.
# 126                                              Onica
# 127                                            Netflix
# 128                                               IEHP
# 129                                              KORE1
# 130                       Clinicas Del Camino Real Inc
# 131                                       Pacific Life
# 132                                              OpenX
# 133                                        CrowdStrike
# 134                                           Facebook
# 135                              Loma Linda University
# 136                                             STRIVR
# 137                                   Hearts & Science
# 138                                           Fox Tech
# 139                                       R&D Partners
# 140                                         ConsultNet
# 141                            Axiologic Solutions LLC
# 142                                   D Cube Analytics
# 143                                  Dollar Shave Club
# 144                          Nexstar Media Group, Inc.
# 145                                            Joybird
# 146                             InterMedia Advertising
# 147                      Infinity Consulting Solutions
# 148                         OnPoint Search Consultants
# 149                                          CoreLogic
# 150                   Dynamic Healthcare Systems, Inc.
# 151                     NASA Jet Propulsion Laboratory
# 152                                      Century Group
# 153                                              Areté
# 154                                        Factual Inc
# 155                                 Jobspring Partners
# 156                                            ringDNA
# 157                                          Microdesk
# 158                                 Aveanna Healthcare
# 159                                      Thrive Market
# 160                                             Google
# 161                              TAE Technologies, Inc
# 162                                        CyberCoders
# 163                                     Anser Advisory
# 164                                   SCAN Health Plan
# 165                               Edwards Lifesciences
# 166                                         Mothership
# 167                      Pediatria Healthcare for Kids
# 168              Advanced Sterilization Products (ASP)
# 169                                      NEXT Trucking
# 170                                        Bitwise Inc
# 171                                HealthPlan Services
# 172                                           Experian
# 173                                 Motion Recruitment
# 174                                           KloudOne
# 175                                         Perficient
# 176                                         Databricks
# 177                                       Unicon, Inc.
# 178                     Jobs Interviewing Now from HCS
# 179                                         CitiusTech
# 180                                       Mattel, Inc.
# 181                                 UnitedHealth Group
# 182                                                AXS
# 183                                             Rivian
# 184                     Jobs Interviewing Now from MJH
# 185           Motorsport Aftermarket Group, Inc. (MAG)
# 186                                Activision Blizzard
# 187                                                 EY
# 188                Platinum Enterprise Solutions, Inc.
# 189                                           SynapOne
# 190                                      iLink Systems
# 191                                   Infotree Service
# 192                                       UM Worldwide
# 193                                  Kaiser Permanente
# 194                           Thermo Fisher Scientific
# 195                           Camden Kelly Corporation
# 196                                            KPMG US
# 197                                  Farmers Insurance
# 198                                                 ZS
# 199                                     Houlihan Lokey
#
#                                              location
# 0                                Pasadena, California
# 1                                Temecula, California
# 2                  Ontario, California, United States
# 3              Los Angeles, California, United States
# 4              Los Angeles, California, United States
# 5               El Segundo, California, United States
# 6                                      Irvine, CA, US
# 7                       Los Angeles Metropolitan Area
# 8              Los Angeles, California, United States
# 9                                   Santa Ana, CA, US
# 10                                Ontario, California
# 11                                 El Segundo, CA, US
# 12                                Culver City, CA, US
# 13                                 Carson, California
# 14                              Calabasas, California
# 15   92610, Foothill Ranch, California, United States
# 16                                 Costa Mesa, CA, US
# 17                             Woodland Hills, CA, US
# 18                                     Irvine, CA, US
# 19                                Los Angeles, CA, US
# 20             Aliso Viejo, California, United States
# 21                              Newport Beach, CA, US
# 22                                     Pomona, CA, US
# 23                                Los Angeles, CA, US
# 24                                  Fullerton, CA, US
# 25                                  Fullerton, CA, US
# 26                                   Glendale, CA, US
# 27                                     Irvine, CA, US
# 28                                Los Angeles, CA, US
# 29                               Santa Monica, CA, US
# 30                                     Irvine, CA, US
# 31             Los Angeles, California, United States
# 32                                  Irwindale, CA, US
# 33                                Los Angeles, CA, US
# 34                                     Malibu, CA, US
# 35                                     Irvine, CA, US
# 36                               Santa Monica, CA, US
# 37                                Culver City, CA, US
# 38                                Los Angeles, CA, US
# 39                           Twentynine Palms, CA, US
# 40                                Los Angeles, CA, US
# 41                                   Pasadena, CA, US
# 42                                    Burbank, CA, US
# 43                             Woodland Hills, CA, US
# 44                                Culver City, CA, US
# 45                                     Irvine, CA, US
# 46                        Culver City, California, US
# 47                               Santa Monica, CA, US
# 48                                 El Segundo, CA, US
# 49                                Los Angeles, CA, US
# 50                                Los Angeles, CA, US
# 51                              Thousand Oaks, CA, US
# 52                               Sherman Oaks, CA, US
# 53                             West Hollywood, CA, US
# 54                           Huntington Beach, CA, US
# 55                                 El Segundo, CA, US
# 56                                Culver City, CA, US
# 57                                     Irvine, CA, US
# 58                                   Pasadena, CA, US
# 59             Los Angeles, California, United States
# 60                           Santa Monica, California
# 61                                Diamond Bar, CA, US
# 62                        Culver City, California, US
# 63                                Los Angeles, CA, US
# 64                                     Orange, CA, US
# 65                               Santa Monica, CA, US
# 66                                     Orange, CA, US
# 67                                 El Segundo, CA, US
# 68                               Santa Monica, CA, US
# 69                  Irvine, California, United States
# 70                                     Irvine, CA, US
# 71                           Rancho Cucamonga, CA, US
# 72                               Santa Monica, CA, US
# 73                                Los Angeles, CA, US
# 74                                   Redlands, CA, US
# 75                    Brea, California, United States
# 76                                       Brea, CA, US
# 77                                    Gardena, CA, US
# 78                                    Anaheim, CA, US
# 79                                     Irvine, CA, US
# 80                                    Burbank, CA, US
# 81                                   Glendale, CA, US
# 82                             Universal City, CA, US
# 83                                       Brea, CA, US
# 84                              Thousand Oaks, CA, US
# 85                           Huntington Beach, CA, US
# 86                                 Northridge, CA, US
# 87                                Culver City, CA, US
# 88                             Marina del Rey, CA, US
# 89                                Los Angeles, CA, US
# 90                                     Orange, CA, US
# 91                               Santa Monica, CA, US
# 92                                    Anaheim, CA, US
# 93                                 Irvine, California
# 94                                Los Angeles, CA, US
# 95                             Woodland Hills, CA, US
# 96                                 El Segundo, CA, US
# 97                                Los Angeles, CA, US
# 98                                   Industry, CA, US
# 99                                     Irvine, CA, US
# 100                                  Highland, CA, US
# 101                                 Santa Ana, CA, US
# 102          Thousand Oaks, California, United States
# 103                               Los Angeles, CA, US
# 104                            Woodland Hills, CA, US
# 105                               Los Angeles, CA, US
# 106                                 Santa Ana, CA, US
# 107                                El Segundo, CA, US
# 108            Los Angeles, California, United States
# 109                               Los Angeles, CA, US
# 110                                    Irvine, CA, US
# 111                               Los Angeles, CA, US
# 112                               Los Angeles, CA, US
# 113                               Los Angeles, CA, US
# 114                                   Arcadia, CA, US
# 115                            Woodland Hills, CA, US
# 116                                El Segundo, CA, US
# 117                                    Irvine, CA, US
# 118                              Santa Monica, CA, US
# 119                               Culver City, CA, US
# 120                Ontario, California, United States
# 121                            San Bernardino, CA, US
# 122                                   Gardena, CA, US
# 123            Los Angeles, California, United States
# 124                                  Torrance, CA, US
# 125                                Costa Mesa, CA, US
# 126                                    Irvine, CA, US
# 127                               Los Angeles, CA, US
# 128                          Rancho Cucamonga, CA, US
# 129                                  Glendale, CA, US
# 130                                 Camarillo, CA, US
# 131                             Newport Beach, CA, US
# 132                                  Pasadena, CA, US
# 133                                El Segundo, CA, US
# 134                               Los Angeles, CA, US
# 135                            San Bernardino, CA, US
# 136                               Los Angeles, CA, US
# 137            Los Angeles, California, United States
# 138                               Los Angeles, CA, US
# 139                                    Orange, CA, US
# 140                                    Irvine, CA, US
# 141                                    Carson, CA, US
# 142                               Los Angeles, CA, US
# 143                            Marina del Rey, CA, US
# 144                               Los Angeles, CA, US
# 145                                  Commerce, CA, US
# 146                               Los Angeles, CA, US
# 147                                   Burbank, CA, US
# 148            Los Angeles, California, United States
# 149                 Irvine, California, United States
# 150                                 Santa Ana, CA, US
# 151                          Pasadena, California, US
# 152                               Los Angeles, CA, US
# 153                                Northridge, CA, US
# 154                          Greater Los Angeles Area
# 155                              Santa Monica, CA, US
# 156                              Sherman Oaks, CA, US
# 157                               Los Angeles, CA, US
# 158                                Seal Beach, CA, US
# 159                               Los Angeles, CA, US
# 160                               Los Angeles, CA, US
# 161                            Foothill Ranch, CA, US
# 162                              Santa Monica, CA, US
# 163                                    Pomona, CA, US
# 164                                Long Beach, CA, US
# 165                                    Irvine, CA, US
# 166                       Culver City, California, US
# 167                                Seal Beach, CA, US
# 168                                    Irvine, CA, US
# 169             El Segundo, California, United States
# 170                              Santa Monica, CA, US
# 171                                Long Beach, CA, US
# 172                                Costa Mesa, CA, US
# 173                                    Irvine, CA, US
# 174                     Los Angeles Metropolitan Area
# 175                               Los Angeles, CA, US
# 176                               Los Angeles, CA, US
# 177                                  Torrance, CA, US
# 178                            Woodland Hills, CA, US
# 179                               Lake Forest, CA, US
# 180                                El Segundo, CA, US
# 181                                      Eden, CA, US
# 182                               Los Angeles, CA, US
# 183                                    Irvine, CA, US
# 184                            Woodland Hills, CA, US
# 185                                  La Palma, CA, US
# 186                              Santa Monica, CA, US
# 187                               Los Angeles, CA, US
# 188                               Los Angeles, CA, US
# 189                             Thousand Oaks, CA, US
# 190                                   Ventura, CA, US
# 191                             Thousand Oaks, CA, US
# 192                               Los Angeles, CA, US
# 193                               Los Angeles, CA, US
# 194                                West Hills, CA, US
# 195                                  Alhambra, CA, US
# 196                                    Irvine, CA, US
# 197                            Woodland Hills, CA, US
# 198                               Los Angeles, CA, US
# 199                               Los Angeles, CA, US

# %%
pd.set_option('display.max_rows', None)
dataset.rename(columns={0:'position'},inplace=True)

# %%
dataset.head()
# Out:
#          position               company              location
# 0  Data Scientist  Gene Therapy Startup  Pasadena, California

# %%
job_details = []
for job in range(len(link_list)):
    try:
        for detail in link_list[job].find_all('span','jobs-ppc-criteria__value'):
            job_details.append(detail.get_text())
            print(detail)
    except: 
        print('no data here')
        pass
# Out:
# <span class="jobs-ppc-criteria__value t-14 t-black t-normal ml2 block">
#               Computer Science
#             </span>
# <span class="jobs-ppc-criteria__value t-14 t-black t-normal ml2 block">
#               Data Science
#             </span>
# <span class="jobs-ppc-criteria__value t-14 t-black t-normal ml2 block">
#               Bioinformatics
#             </span>
# <span class="jobs-ppc-criteria__value t-14 t-black t-normal ml2 block">
#               DNA Sequencing
#             </span>
# <span class="jobs-ppc-criteria__value t-14 t-black t-normal ml2 block">
#               Pipeline Development
#             </span>
# <span class="jobs-ppc-criteria__value t-14 t-black t-normal ml2 block">
#               Bioengineering
#             </span>
# <span class="jobs-ppc-criteria__value t-14 t-black t-normal ml2 block">
#               Sequencing
#             </span>
# <span class="jobs-ppc-criteria__value t-14 t-black t-normal ml2 block">
#               Machine Learning
#             </span>
# <span class="jobs-ppc-criteria__value t-14 t-black t-normal ml2 block">
#             Bachelor's Degree
#           </span>

# %%
# final_job_skills= pd.DataFrame(job_details)
# final_job_skills= final_job_details.apply(lambda x: x.str.strip())
# final_job_skills = final_job_skills.rename(columns={0:'skills'})

# %%
# final_job_skills.to_csv('../data/updated_job_skills.csv')

# %%
# dataset.to_csv('../data/jobs_listing.csv')

# %%
db = client.raw_html_db
collection_1 = db.html

# %%
raw = pd.DataFrame(list(collection_1.find()))

# %%
html_soup = []

for i in raw.job:
    for j in i:
        html_soup.extend(soup(j,'html.parser'))

# %%
titles = []
for x in range(len(html_soup)):
    for a in html_soup[x].find_all('a','job-card-search__link-wrapper js-focusable disabled ember-view'):
            titles.append(a.text.strip())

# %%
tmp = []
for job in range(len(link_list)):
    try:
        for detail in link_list[job].find_all('span','jobs-ppc-criteria__value'):
            tmp.append((job,detail.get_text()))
    except: 
        print('no data here')
        pass

# %%
final_job_skills_index  = pd.DataFrame(tmp,columns=['job_index','skills'])
final_job_skills_index.skills = final_job_skills_index.skills.map(lambda x: x.strip())
final_job_skills_index 
# final_job_skills_index.to_csv('../data/skills_indexed.csv')
# Out:
#    job_index                skills
# 0          0      Computer Science
# 1          0          Data Science
# 2          0        Bioinformatics
# 3          0        DNA Sequencing
# 4          0  Pipeline Development
# 5          0        Bioengineering
# 6          0            Sequencing
# 7          0      Machine Learning
# 8          0     Bachelor's Degree

# %%
tmp = []
for job in range(len(link_list)):
    try:
        for detail in link_list[job].find_all('span','jobs-ppc-criteria__value'):
            print((job,detail.get_text()))
    except: 
        print('no data here')
        pass
# Out:
# (0, '\n              Computer Science\n            ')
# (0, '\n              Data Science\n            ')
# (0, '\n              Bioinformatics\n            ')
# (0, '\n              DNA Sequencing\n            ')
# (0, '\n              Pipeline Development\n            ')
# (0, '\n              Bioengineering\n            ')
# (0, '\n              Sequencing\n            ')
# (0, '\n              Machine Learning\n            ')
# (0, "\n            Bachelor's Degree\n          ")

# %%
# employers = []
# for x in range(len(html_soup)):
#     for a in html_soup[x].find_all('a','job-card-search__company-name-link t-normal ember-view', href=True):
#         employers.append(a.text.strip())

# %%
# employers

# %%
# locations = []
# for x in range(len(html_soup)):
#     for a in html_soup[x].find_all('span',"job-card-search__location artdeco-entity-lockup__caption ember-view"):
#         locations.append(a.text.strip())
