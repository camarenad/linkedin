# %%
from bs4 import BeautifulSoup as soup 
import pandas as pd
import pymongo 
import datetime
import nltk 
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import matplotlib.pyplot as plt

set(stopwords.words('english'))
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# <ipython-input-30-e9c85a654845> in <module>
# ----> 1 print(stopwords())
#
# TypeError: 'WordListCorpusReader' object is not callable

# %%
# Initialize Mongo 
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.thousand_tabs
collection = db.job_detail
job_links_collection = db.job_links

# %%
data = pd.DataFrame(list(collection.find()))

# %%
link_list = []
for html in data.link_src:
    link_list.append(soup(html,'html.parser'))

# %%
job_summary = []
for idx in range(len(link_list)):
    for txt in link_list[idx].find_all('article','jobs-description__container jobs-description__container--condensed'):
        job_summary.append([txt.get_text()])

# %%
tmp  =job_summary[0]

# %%
tmp = [x.lower() for x in tmp]
tmp

# %%
stop_words = set(stopwords.words('english'))
tmp = [word for word in tmp if word not in stop_words]
tmp
# Out:
# ["\n\n\n \nfocus gts is looking for a manufacturing and clinical supply data scientist for a contract position with a global company.\n\n position is on-site in thousand oaks california, and at this time, relocation is not provided.  \nthis person will build a wide-range of innovative data and analytics solutions, from descriptive to prescriptive, develop advanced analytical models, integrate data, derive insights, and automate and enhance processes  \nthe ideal candidate enjoys tackling challenges and excels at organizing information from numerous sources to provide well-constructed deliverables. \nmust have experience with interpreting and extracting meaning from different types of data sets. must have an understanding of biopharmaceuticals process and related unit operations, including supply chain operations. **expertise in python, sql, and ideally sas\xa0 \nlooking for someone with a can do attitude, willing to go outside of their comfort zone, great communication skills, and attention to detail! \nmanager references will be mandatory for consideration for this role.\n \n \n\n\n\n    how you match\n \n\n\n\n\n \ncriteria provided by job poster\n\n\n\nskills\n\n\n\nmatch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n              python (programming language)\n            \n\n\n\nmatch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n              analytical skills\n            \n\n\n\nmatch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n              data science\n            \n\n\n\nno match\n\n\n\n\n\n\n\n              data integration\n            \n\n\n\nno match\n\n\n\n\n\n\n\n              manufacturing engineering\n            \n\n\n\nno match\n\n\n\n\n\n\n\n              communication\n            \n\n\n\nno match\n\n\n\n\n\n\n\n              biopharmaceuticals\n            \n\n\n\nno match\n\n\n\n\n\n\n\n              supply chain management\n            \n\n\n\nno match\n\n\n\n\n\n\n\n              supply chain operations\n            \n\n\n\nno match\n\n\n\n\n\n\n\n              operations\n            \n\n\n\n\n\nlevel of education\n\n\n\nmatch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n            bachelor's degree\n          \n\n\n\n\n\n\n  contact the job poster\n\n\n\n \n \n\n\n          katie daron\n \ndata science staffing specialist\n\n\n\n\n\n\n\n\n        send inmail\n\n\n\n\n\n\n\n\n"]

# %%
skill_list = ['tableau', 'sql', 'python', ' r ', 'relational database', 'power bi']

# %%
tmpp = 'sql'

# %%
tmpp in skill_list
# Out:
# True

# %%
job_list = job_summary[:10].lower()
job_list
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# <ipython-input-101-534b6558ca3c> in <module>
# ----> 1 job_list = job_summary[:10].lower()
#       2 job_list
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
job_skills = []
for idx, job in enumerate(job_list):
    for skill in skill_list:
        if skill in job:
            job_skills.append((idx, skill))
job_skills
# Out:
# []

# %%
cvec = CountVectorizer(stop_words='english',ngram_range=(2,2))

# %%
term_mat = cvec.fit_transform(tmp)

# %%
term_df = pd.DataFrame(term_mat.toarray(),columns=cvec.get_feature_names())

# %%
term_sums = term_df.sum().sort_values(ascending=False)[:150]

# %%
fig,ax = plt.subplots(figsize=(20,30))
ax.tick_params(axis='both',labelsize=20,pad=.50)
term_sums.sort_values().plot(kind='barh')

# %%
for x in tmp:
